# %% [markdown]
# # Docker‑Stack stoppen (ohne Volumes zu löschen)
# Dieses Skript prüft automatisch, ob Docker und docker compose verfügbar sind, ob die docker-compose.yml existiert, und stoppt anschließend den gesamten Docker‑Stack ohne die Volumes zu löschen.
# Damit bleiben persistente Daten – z. B. MongoDB‑Datenbanken – vollständig erhalten.

# %%
import subprocess
import os

compose_file = "../docker-compose.yml"

def run_command(command):
    """Führt einen Shell-Befehl aus und gibt Erfolg, stdout und stderr zurück."""
    result = subprocess.run(
        command,
        shell=True,
        capture_output=True,
        text=True
    )
    return result.returncode == 0, result.stdout.strip(), result.stderr.strip()

# 1. Prüfen, ob Docker verfügbar ist
ok, stdout, stderr = run_command("docker --version")

if not ok:
    print("❌ Docker ist nicht verfügbar.")
    print("Bitte Docker Desktop installieren und starten.")
else:
    print(f"✅ Docker gefunden: {stdout}")

    # 2. Prüfen, ob docker compose verfügbar ist
    ok, stdout, stderr = run_command("docker compose version")
    if not ok:
        print("❌ 'docker compose' ist nicht verfügbar.")
        print("Bitte sicherstellen, dass Docker Desktop aktuell ist.")
    else:
        print(f"✅ docker compose gefunden: {stdout}")

        # 3. Prüfen, ob docker-compose.yml existiert
        if not os.path.exists(compose_file):
            print(f"❌ '{compose_file}' wurde nicht gefunden.")
            print("Bitte sicherstellen, dass die Datei im Projektordner liegt.")
        else:
            print(f"✅ '{compose_file}' gefunden.")

            # 4. docker compose down (ohne -v)
            print("🛑 Stoppe docker-compose Stack (Container + Netzwerk, Volumes bleiben erhalten) …")
            ok, stdout, stderr = run_command("docker compose down")

            if ok:
                print("✅ Stack wurde gestoppt (Volumes wurden NICHT gelöscht).")
            else:
                print("❌ Stack konnte nicht gestoppt werden.")
                print(stderr)
